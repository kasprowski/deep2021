# %%
import random
from tensorflow.python.keras import layers
from tensorflow.python.keras.models import Sequential
import roman_numerals as cnv
import numpy as np
import random

# %%
from encoder import CharacterTable 

# Parameters for the model and dataset.
DATASET_SIZE = 500
INPUT = 14
OUTPUT = 4
# object to encode roman numbers to one-hot 
romans = 'MDCLXVI '
rtable = CharacterTable(romans)

# object to encode arabic numbers to one-hot
chars = '0123456789 '
dtable = CharacterTable(chars)

# %%
seq_samples = []
seq_labels = []
used = []
repetitions = 0
generated = 0
print('Generating data...')
while len(seq_samples) < DATASET_SIZE:
    number = random.randint(1,2000)
    # skip if already in the dataset
    if number in used: continue
    used.append(number)
    # roman input
    roman = cnv.convert(number) 
    roman += ' ' * (INPUT - len(roman))
    
    # arabic output
    arabic = str(number)
    arabic += ' ' * (OUTPUT - len(arabic)) 
    
    seq_samples.append(roman)
    seq_labels.append(arabic)
print('Total roman numbers:', len(seq_samples))
#print("samples",seq_samples)
#print("labels",seq_labels)
# Out:
# Generating data...
# Total roman numbers: 500

# %%
# one-hot encoding of all romans and arabic numbers
print('Vectorization...')
samples = np.zeros((DATASET_SIZE, INPUT, len(romans)), dtype=np.bool)
labels = np.zeros((DATASET_SIZE, OUTPUT, len(chars)), dtype=np.bool)
for i, sentence in enumerate(seq_samples):
    samples[i] = rtable.encode(sentence, INPUT)
for i, sentence in enumerate(seq_labels):
    labels[i] = dtable.encode(sentence, OUTPUT)
print("samples",samples.shape)    
print("labels",labels.shape)
# Out:
# Vectorization...
# samples (500, 14, 8)
# labels (500, 4, 11)

# %%
import sklearn.model_selection
(trainSamples, testSamples, trainLabels, testLabels) = sklearn.model_selection.train_test_split(samples,labels,random_state=42)
print("Training samples",len(trainSamples))
print("Test samples",len(testSamples))
# Out:
# Training samples 375
# Test samples 125

# %%
# Build the network
print('Build model...')
model = Sequential()
model.add(layers.LSTM(128, input_shape=(INPUT, len(romans))))
model.add(layers.RepeatVector(OUTPUT))
model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               70144
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4, 128)            131584
# _________________________________________________________________
# dense (Dense)                (None, 4, 11)             1419
# =================================================================
# Total params: 203,147
# Trainable params: 203,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
def avg(list):
    return sum(list)/len(list)

EPOCHS = 50
# Train the model each generation and show predictions against the validation dataset.
for iteration in range(1, 500):
    print()
    print('-' * 50)
    print('Iteration', iteration*EPOCHS)
    H = model.fit(trainSamples, trainLabels, batch_size=128, epochs=EPOCHS, 
                  validation_data=(testSamples, testLabels), verbose=0)
    print("Validation accuracy: {}".format(avg(H.history["val_accuracy"])))
    # Select 10 samples from the validation set at random to visualize errors.
    accuracy = 0
    for i in range(len(testSamples)):
        
        rowx, rowy = testSamples[np.array([i])], testLabels[np.array([i])]
        preds = model.predict_classes(rowx, verbose=0)
        roman = rtable.decode(rowx[0])
        correct = dtable.decode(rowy[0])
        prediction = dtable.decode(preds[0], calc_argmax=False)
        correctTxt = ""
        if correct == prediction:
            correctTxt+='OK!'
            accuracy+=1
        v = random.random()
        if v>0.9:
            print('expression:', roman, end=' ')
            print('correct:', correct, end=' ')
            print('predicted:', prediction, end=' ')
            print(correctTxt)
        
    print('accuracy=',accuracy,"/",len(testSamples),"=",accuracy/len(testSamples))
# Out:
# --------------------------------------------------
# Iteration 50
# Validation accuracy: 0.36079999774694443
# WARNING:tensorflow:From <ipython-input-7-ee0dce255be6>:18: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# expression: DCL            correct: 650  predicted: 100
# expression: MDXX           correct: 1520 predicted: 1000
# expression: MCCCXXIV       correct: 1324 predicted: 1323
# expression: DCCCL          correct: 850  predicted: 155
# expression: MLXIII         correct: 1063 predicted: 122
# expression: CCCXXXVI       correct: 336  predicted: 329
# expression: MCXCV          correct: 1195 predicted: 1555
# expression: MDCCCII        correct: 1802 predicted: 1922
# expression: CDLXXIX        correct: 479  predicted: 729
# expression: C              correct: 100  predicted: 100  OK!
# expression: CXIX           correct: 119  predicted: 22
# expression: MDCCCLI        correct: 1851 predicted: 1445
# expression: CLXIII         correct: 163  predicted: 229
# accuracy= 1 / 125 = 0.008
#
# --------------------------------------------------
# Iteration 100
# Validation accuracy: 0.49260000288486483
# expression: CMXXXI         correct: 931  predicted: 999
# expression: MCCCXXXVI      correct: 1336 predicted: 1339
# expression: MDCCCI         correct: 1801 predicted: 1920
# expression: DXVIII         correct: 518  predicted: 108
# expression: MDLXXXVIII     correct: 1588 predicted: 1688
# expression: MCCXXXIII      correct: 1233 predicted: 1333
# expression: MDVII          correct: 1507 predicted: 1557
# expression: CCXXXIV        correct: 234  predicted: 322
# expression: MCCXX          correct: 1220 predicted: 1300
# expression: MDIV           correct: 1504 predicted: 1506
# expression: C              correct: 100  predicted: 200
# expression: III            correct: 3    predicted: 522
# expression: MCMLXXI        correct: 1971 predicted: 1949
# expression: MDCXCIX        correct: 1699 predicted: 1729
# expression: MDCCCXCIV      correct: 1894 predicted: 1724
# expression: MDCXIX         correct: 1619 predicted: 1429
# accuracy= 3 / 125 = 0.024
#
# --------------------------------------------------
# Iteration 150
# Validation accuracy: 0.5821599984169006
# expression: DXCVII         correct: 597  predicted: 107
# expression: DCCXLIX        correct: 749  predicted: 769
# expression: DCLVI          correct: 656  predicted: 456
# expression: MCMXCI         correct: 1991 predicted: 1919
# expression: DCXXXIX        correct: 639  predicted: 799
# expression: MDXC           correct: 1590 predicted: 1410
# expression: MDCLXI         correct: 1661 predicted: 1411
# expression: CCXXXIV        correct: 234  predicted: 322
# expression: DXVII          correct: 517  predicted: 507
# expression: CXIX           correct: 119  predicted: 211
# expression: CLXXVI         correct: 176  predicted: 366
# expression: MCDXXIII       correct: 1423 predicted: 1533
# expression: DCCVII         correct: 707  predicted: 107
# accuracy= 6 / 125 = 0.048
#
# --------------------------------------------------
# Iteration 200
# Validation accuracy: 0.6278800022602081
# expression: DLXXV          correct: 575  predicted: 46
# expression: MDCCII         correct: 1702 predicted: 1592
# expression: MDXX           correct: 1520 predicted: 1500
# expression: MCCCXXXVI      correct: 1336 predicted: 1389
# expression: MDCCXXVIII     correct: 1728 predicted: 1718
# expression: MCCXXXVII      correct: 1237 predicted: 1337
# expression: MCXXXIV        correct: 1134 predicted: 1222
# expression: MDCCCLIX       correct: 1859 predicted: 1844
# expression: MCLIX          correct: 1159 predicted: 1141
# expression: MCDXXVIII      correct: 1428 predicted: 1488
# expression: CCXCII         correct: 292  predicted: 392
# expression: MDCXX          correct: 1620 predicted: 1420
# expression: MDLVI          correct: 1556 predicted: 1555
# accuracy= 11 / 125 = 0.088
#
# --------------------------------------------------
# Iteration 250
# Validation accuracy: 0.6626800012588501
# expression: CXXIV          correct: 124  predicted: 244
# expression: DLXXV          correct: 575  predicted: 56
# expression: MCDXXII        correct: 1422 predicted: 1622
# expression: MCCI           correct: 1201 predicted: 1200
# expression: MCXXII         correct: 1122 predicted: 1002
# expression: DCLVI          correct: 656  predicted: 456
# expression: CCCXXXVI       correct: 336  predicted: 384
# expression: CDLXXIX        correct: 479  predicted: 781
# expression: DXVII          correct: 517  predicted: 507
# expression: MIX            correct: 1009 predicted: 1001
# expression: CLXXVI         correct: 176  predicted: 266
# expression: MCMLV          correct: 1955 predicted: 1955 OK!
# expression: CMXXXIV        correct: 934  predicted: 922
# expression: MCCCLV         correct: 1355 predicted: 1755
# accuracy= 23 / 125 = 0.184
#
# --------------------------------------------------
# Iteration 300
# Validation accuracy: 0.7077999973297119
# expression: CCCXVII        correct: 317  predicted: 397
# expression: CCLVII         correct: 257  predicted: 257  OK!
# expression: CXXXVIII       correct: 138  predicted: 133
# expression: CMXVIII        correct: 918  predicted: 998
# expression: CMXXXI         correct: 931  predicted: 929
# expression: DXVIII         correct: 518  predicted: 508
# expression: MCXCI          correct: 1191 predicted: 1209
# expression: MCMXXI         correct: 1921 predicted: 1919
# expression: DCCCL          correct: 850  predicted: 810
# expression: MCV            correct: 1105 predicted: 1105 OK!
# expression: CCCXXXVI       correct: 336  predicted: 389
# expression: MDLXXIX        correct: 1579 predicted: 1529
# expression: MXXXIII        correct: 1033 predicted: 1033 OK!
# expression: MDIV           correct: 1504 predicted: 1506
# expression: MDCLVIII       correct: 1658 predicted: 1758
# expression: CLXXVI         correct: 176  predicted: 266
# expression: MCCLXXVIII     correct: 1278 predicted: 1488
# expression: MCXXXI         correct: 1131 predicted: 1239
# expression: DCCCXII        correct: 812  predicted: 892
# accuracy= 32 / 125 = 0.256
#
# --------------------------------------------------
# Iteration 350
# Validation accuracy: 0.7255199944972992
# expression: CCCXVII        correct: 317  predicted: 397
# expression: DCCXLIX        correct: 749  predicted: 769
# expression: MCXXII         correct: 1122 predicted: 1032
# expression: MCCXXXIII      correct: 1233 predicted: 1333
# expression: DCCCL          correct: 850  predicted: 815
# expression: MCV            correct: 1105 predicted: 1105 OK!
# expression: CXX            correct: 120  predicted: 120  OK!
# expression: MDXC           correct: 1590 predicted: 1400
# expression: MDLXXIX        correct: 1579 predicted: 1529
# expression: MCXCV          correct: 1195 predicted: 1125
# expression: MCDXCIV        correct: 1494 predicted: 1624
# expression: MDCXCIX        correct: 1699 predicted: 1629
# expression: MLXVIII        correct: 1068 predicted: 1168
# expression: MCCLXXI        correct: 1271 predicted: 1280
# expression: DCCCVII        correct: 807  predicted: 807  OK!
# expression: MCLXXXIII      correct: 1183 predicted: 1188
# expression: CCLVI          correct: 256  predicted: 266
# accuracy= 32 / 125 = 0.256
#
# --------------------------------------------------
# Iteration 400
# Validation accuracy: 0.7344000029563904
# expression: CCLVII         correct: 257  predicted: 257  OK!
# expression: MCXXIX         correct: 1129 predicted: 1039
# expression: MDCLXV         correct: 1665 predicted: 1665 OK!
# expression: MDXC           correct: 1590 predicted: 1400
# expression: MCMLV          correct: 1955 predicted: 1955 OK!
# expression: CMXXXIV        correct: 934  predicted: 9222
# expression: CLXIII         correct: 163  predicted: 173
# expression: MDLVI          correct: 1556 predicted: 1556 OK!
# accuracy= 36 / 125 = 0.288
#
# --------------------------------------------------
# Iteration 450
# Validation accuracy: 0.7402399957180024
# expression: CXXIV          correct: 124  predicted: 224
# expression: CCCXI          correct: 311  predicted: 311  OK!
# expression: MCMXCI         correct: 1991 predicted: 1919
# expression: DCXXXIX        correct: 639  predicted: 639  OK!
# expression: DCCCL          correct: 850  predicted: 845
# expression: MLXIII         correct: 1063 predicted: 1043
# expression: MDIV           correct: 1504 predicted: 1506
# expression: MDCCCXCIV      correct: 1894 predicted: 1894 OK!
# expression: MXIX           correct: 1019 predicted: 1099
# expression: MCDXXIII       correct: 1423 predicted: 1233
# expression: CMXXXIV        correct: 934  predicted: 9272
# expression: DCLXXV         correct: 675  predicted: 485
# accuracy= 36 / 125 = 0.288
#
# --------------------------------------------------
# Iteration 500
# Validation accuracy: 0.741360000371933
# expression: DCL            correct: 650  predicted: 400
# expression: DCCXLIX        correct: 749  predicted: 769
# expression: CLXII          correct: 162  predicted: 162  OK!
# expression: XXVIII         correct: 28   predicted: 57
# expression: CDLIII         correct: 453  predicted: 453  OK!
# expression: DCCXXIV        correct: 724  predicted: 774
# expression: MDCCCII        correct: 1802 predicted: 1752
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-ee0dce255be6>", line 18, in <module>
#     preds = model.predict_classes(rowx, verbose=0)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\util\deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\sequential.py", line 453, in predict_classes
#     proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\training.py", line 130, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\training.py", line 1569, in predict
#     data_handler = data_adapter.DataHandler(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py", line 1105, in __init__
#     self._adapter = adapter_cls(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py", line 362, in __init__
#     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1727, in flat_map
#     return FlatMapDataset(self, map_func)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 4122, in __init__
#     self._map_func = StructuredFunctionWrapper(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 3371, in __init__
#     self._function = wrapper_fn.get_concrete_function()
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py", line 2938, in get_concrete_function
#     graph_function = self._get_concrete_function_garbage_collected(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py", line 2906, in _get_concrete_function_garbage_collected
#     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py", line 3213, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py", line 3065, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\func_graph.py", line 986, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 3364, in wrapper_fn
#     ret = _wrapper_helper(*args)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 3299, in _wrapper_helper
#     ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 255, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 532, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 339, in _call_unconverted
#     return f(*args, **kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py", line 348, in slice_batch_indices
#     first_k_indices = array_ops.reshape(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\util\dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\ops\array_ops.py", line 195, in reshape
#     result = gen_array_ops.reshape(tensor, shape, name)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\ops\gen_array_ops.py", line 8232, in reshape
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\func_graph.py", line 591, in _create_op_internal
#     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\ops.py", line 3477, in _create_op_internal
#     ret = Operation(
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\ops.py", line 1974, in __init__
#     self._c_op = _create_c_op(self._graph, node_def, inputs,
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\ops.py", line 1812, in _create_c_op
#     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\programs\miniconda3\envs\deep\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\programs\miniconda3\envs\deep\lib\inspect.py", line 1465, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "C:\programs\miniconda3\envs\deep\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "C:\programs\miniconda3\envs\deep\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "C:\programs\miniconda3\envs\deep\lib\tokenize.py", line 392, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-7-ee0dce255be6> in <module>
#      17         rowx, rowy = testSamples[np.array([i])], testLabels[np.array([i])]
# ---> 18         preds = model.predict_classes(rowx, verbose=0)
#      19         roman = rtable.decode(rowx[0])
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\sequential.py in predict_classes(self, x, batch_size, verbose)
#     452     """
# --> 453     proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     454     if proba.shape[-1] > 1:
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1568       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1569       data_handler = data_adapter.DataHandler(
#    1570           x=x,
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1104     adapter_cls = select_data_adapter(x, y)
# -> 1105     self._adapter = adapter_cls(
#    1106         x,
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     361
# --> 362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func)
#    1726     """
# -> 1727     return FlatMapDataset(self, map_func)
#    1728
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func)
#    4121     self._input_dataset = input_dataset
# -> 4122     self._map_func = StructuredFunctionWrapper(
#    4123         map_func, self._transformation_name(), dataset=input_dataset)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3370         # TODO(b/141462134): Switch to using garbage collection.
# -> 3371         self._function = wrapper_fn.get_concrete_function()
#    3372         if add_to_graph:
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    2937     """
# -> 2938     graph_function = self._get_concrete_function_garbage_collected(
#    2939         *args, **kwargs)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2905     with self._lock:
# -> 2906       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2907       seen_names = set()
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapper_fn(*args)
#    3363       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3364         ret = _wrapper_helper(*args)
#    3365         ret = structure.to_tensor_list(self._output_structure, ret)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in _wrapper_helper(*args)
#    3298
# -> 3299       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3300       # If `func` returns a list of tensors, `nest.flatten()` and
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     254         with conversion_ctx:
# --> 255           return converted_call(f, args, kwargs, options=options)
#     256       except Exception as e:  # pylint:disable=broad-except
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     531   if not options.user_requested and conversion.is_whitelisted(f):
# --> 532     return _call_unconverted(f, args, kwargs, options)
#     533
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     338   if kwargs is not None:
# --> 339     return f(*args, **kwargs)
#     340   return f(*args)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in slice_batch_indices(indices)
#     347       first_k_indices = array_ops.slice(indices, [0], [num_in_full_batch])
# --> 348       first_k_indices = array_ops.reshape(
#     349           first_k_indices, [num_full_batches, batch_size])
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\ops\array_ops.py in reshape(tensor, shape, name)
#     194   """
# --> 195   result = gen_array_ops.reshape(tensor, shape, name)
#     196   tensor_util.maybe_set_static_shape(result, shape)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in reshape(tensor, shape, name)
#    8231   # Add nodes to the TensorFlow graph.
# -> 8232   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    8233         "Reshape", tensor=tensor, shape=shape, name=name)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     741       # pylint: disable=protected-access
# --> 742       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     743                                  name=scope, input_types=input_types,
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     590       inputs[i] = inp
# --> 591     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     592         op_type, inputs, dtypes, input_types, name, attrs, op_def,
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3476     with self._mutation_lock():
# -> 3477       ret = Operation(
#    3478           node_def,
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1973         op_def = self._graph._get_op_def(node_def.op)
# -> 1974       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    1975                                 control_input_ops, op_def)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1811   try:
# -> 1812     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1813   except errors.InvalidArgumentError as e:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                         stb = value._render_traceback_()
#    2046                     except Exception:
# -> 2047                         stb = self.InteractiveTB.structured_traceback(etype,
#    2048                                             value, tb, tb_offset=tb_offset)
#    2049
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# C:\programs\miniconda3\envs\deep\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
