# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %% [markdown]
# ## Load images

# %%
import cv2
import os
def load_img(indir):
    samples = []
    labels = []
    for class_dir in os.listdir(indir):
        the_class = class_dir
        for file in os.listdir(indir+'/'+class_dir):
            image = cv2.imread("{}/{}/{}".format(indir,class_dir,file))
            image = cv2.resize(image, (128,128))
            samples.append(image)
            labels.append(the_class)
    samples = np.array(samples)
    labels = np.array(labels)
    return samples,labels
samples, labels = load_img('dataset')
print('loaded',len(samples),' samples')

labels[labels=='new_cats']='cats'
labels[labels=='new_dogs']='dogs'

print('classes',set(labels))

# normalization
samples = samples / 255.0
# Out:
# loaded 6193  samples
# classes {'cats', 'dogs'}

# %% [markdown]
# ## Show examples

# %%
import matplotlib.pyplot as plt
import random
plt.figure(figsize=(10, 10))
for i in range(9):
    n = random.randrange(len(samples))
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(samples[n])
    plt.title(labels[n])
    plt.axis("off")

# %% [markdown]
# ## Create a CNN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

model = Sequential()
model.add(Conv2D(16, (3, 3), padding="same",input_shape=(128,128,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation("sigmoid"))
model.add(Dense(2))
model.add(Activation("softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 16)      448
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 16)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               8389120
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# _________________________________________________________________
# activation_4 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 8,413,730
# Trainable params: 8,413,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Prepare labels (one-hot)

# %%
from sklearn.preprocessing import LabelEncoder 
encoder = LabelEncoder() # encoder
intlabels = encoder.fit_transform(labels)
labels = tf.keras.utils.to_categorical(intlabels)
print("One-hot labels",labels.shape)
# Out:
# One-hot labels (6193, 2)

# %% [markdown]
# ## Train model

# %%
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping
print(samples.shape)
import sklearn.model_selection
(trainSamples, testSamples, trainLabels, testLabels) = sklearn.model_selection.train_test_split(samples,labels,random_state=42)
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

checkpt = ModelCheckpoint (filepath='model.h5', save_best_only=True)
estopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

EPOCHS = 100
H = model.fit(trainSamples, trainLabels, epochs=EPOCHS, batch_size=128, validation_data=(testSamples,testLabels),
             callbacks = [estopping,checkpt]) 
print("Done")
# Out:
# (6193, 128, 128, 3)
# Train on 4644 samples, validate on 1549 samples
# Epoch 1/100
# 4644/4644 [==============================] - 44s 9ms/sample - loss: 0.9165 - accuracy: 0.5286 - val_loss: 0.6702 - val_accuracy: 0.5578
# Epoch 2/100
# 4644/4644 [==============================] - 43s 9ms/sample - loss: 0.6325 - accuracy: 0.6660 - val_loss: 0.6366 - val_accuracy: 0.6062
# Epoch 3/100
# 4644/4644 [==============================] - 44s 10ms/sample - loss: 0.5440 - accuracy: 0.7272 - val_loss: 0.5303 - val_accuracy: 0.7444
# Epoch 4/100
# 4644/4644 [==============================] - 51s 11ms/sample - loss: 0.4821 - accuracy: 0.7758 - val_loss: 0.5524 - val_accuracy: 0.6830
# Epoch 5/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.4124 - accuracy: 0.8079 - val_loss: 0.5709 - val_accuracy: 0.6669
# Epoch 6/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.3782 - accuracy: 0.8331 - val_loss: 0.4653 - val_accuracy: 0.7773
# Epoch 7/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.3287 - accuracy: 0.8592 - val_loss: 0.4368 - val_accuracy: 0.7811
# Epoch 8/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.2746 - accuracy: 0.8809 - val_loss: 0.3584 - val_accuracy: 0.8438
# Epoch 9/100
# 4644/4644 [==============================] - 45s 10ms/sample - loss: 0.2478 - accuracy: 0.8943 - val_loss: 0.4482 - val_accuracy: 0.7786
# Epoch 10/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.2004 - accuracy: 0.9214 - val_loss: 0.2902 - val_accuracy: 0.8844
# Epoch 11/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.1902 - accuracy: 0.9236 - val_loss: 0.3023 - val_accuracy: 0.8657
# Epoch 12/100
# 4644/4644 [==============================] - 44s 10ms/sample - loss: 0.1634 - accuracy: 0.9350 - val_loss: 0.2639 - val_accuracy: 0.8974
# Epoch 13/100
# 4644/4644 [==============================] - 44s 10ms/sample - loss: 0.1690 - accuracy: 0.9352 - val_loss: 0.2454 - val_accuracy: 0.9103
# Epoch 14/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.1385 - accuracy: 0.9488 - val_loss: 0.2322 - val_accuracy: 0.9083
# Epoch 15/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0949 - accuracy: 0.9664 - val_loss: 0.2157 - val_accuracy: 0.9187
# Epoch 16/100
# 4644/4644 [==============================] - 51s 11ms/sample - loss: 0.0917 - accuracy: 0.9664 - val_loss: 0.2831 - val_accuracy: 0.8825
# Epoch 17/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0813 - accuracy: 0.9705 - val_loss: 0.1932 - val_accuracy: 0.9283
# Epoch 18/100
# 4644/4644 [==============================] - 49s 10ms/sample - loss: 0.0688 - accuracy: 0.9789 - val_loss: 0.3611 - val_accuracy: 0.8593
# Epoch 19/100
# 4644/4644 [==============================] - 49s 10ms/sample - loss: 0.0711 - accuracy: 0.9739 - val_loss: 0.2066 - val_accuracy: 0.9245
# Epoch 20/100
# 4644/4644 [==============================] - 50s 11ms/sample - loss: 0.0765 - accuracy: 0.9705 - val_loss: 0.1829 - val_accuracy: 0.9335
# Epoch 21/100
# 4644/4644 [==============================] - 45s 10ms/sample - loss: 0.0523 - accuracy: 0.9845 - val_loss: 0.2039 - val_accuracy: 0.9212
# Epoch 22/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.0363 - accuracy: 0.9894 - val_loss: 0.2202 - val_accuracy: 0.9187
# Epoch 23/100
# 4644/4644 [==============================] - 50s 11ms/sample - loss: 0.0359 - accuracy: 0.9903 - val_loss: 0.1880 - val_accuracy: 0.9303
# Epoch 24/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0644 - accuracy: 0.9761 - val_loss: 0.2193 - val_accuracy: 0.9225
# Epoch 25/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0555 - accuracy: 0.9817 - val_loss: 0.1969 - val_accuracy: 0.9232
# Epoch 26/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0485 - accuracy: 0.9819 - val_loss: 0.2312 - val_accuracy: 0.9096
# Epoch 27/100
# 4644/4644 [==============================] - 49s 10ms/sample - loss: 0.0396 - accuracy: 0.9851 - val_loss: 0.2455 - val_accuracy: 0.9083
# Epoch 28/100
# 4644/4644 [==============================] - 53s 11ms/sample - loss: 0.0332 - accuracy: 0.9899 - val_loss: 0.2000 - val_accuracy: 0.9316
# Epoch 29/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.2625 - val_accuracy: 0.9122
# Epoch 30/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.1805 - val_accuracy: 0.9361
# Epoch 31/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.1813 - val_accuracy: 0.9374
# Epoch 32/100
# 4644/4644 [==============================] - 49s 11ms/sample - loss: 0.0216 - accuracy: 0.9946 - val_loss: 0.2430 - val_accuracy: 0.9212
# Epoch 33/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.0219 - accuracy: 0.9935 - val_loss: 0.1913 - val_accuracy: 0.9342
# Epoch 34/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.1640 - val_accuracy: 0.9477
# Epoch 35/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0218 - accuracy: 0.9925 - val_loss: 0.1749 - val_accuracy: 0.9380
# Epoch 36/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.1951 - val_accuracy: 0.9374
# Epoch 37/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0098 - accuracy: 0.9978 - val_loss: 0.2630 - val_accuracy: 0.9225
# Epoch 38/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0089 - accuracy: 0.9976 - val_loss: 0.1774 - val_accuracy: 0.9432
# Epoch 39/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.1665 - val_accuracy: 0.9548
# Epoch 40/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0050 - accuracy: 0.9996 - val_loss: 0.1713 - val_accuracy: 0.9464
# Epoch 41/100
# 4644/4644 [==============================] - 49s 10ms/sample - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2343 - val_accuracy: 0.9322
# Epoch 42/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9413
# Epoch 43/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.1983 - val_accuracy: 0.9464
# Epoch 44/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0567 - accuracy: 0.9849 - val_loss: 0.3819 - val_accuracy: 0.8773
# Epoch 45/100
# 4644/4644 [==============================] - 47s 10ms/sample - loss: 0.0729 - accuracy: 0.9750 - val_loss: 0.2035 - val_accuracy: 0.9309
# Epoch 46/100
# 4644/4644 [==============================] - 48s 10ms/sample - loss: 0.0300 - accuracy: 0.9903 - val_loss: 0.2198 - val_accuracy: 0.9258
# Epoch 47/100
# 4644/4644 [==============================] - 46s 10ms/sample - loss: 0.0238 - accuracy: 0.9912 - val_loss: 0.1841 - val_accuracy: 0.9393
# Epoch 00047: early stopping
# Done

# %% [markdown]
# ## Show results

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, cohen_kappa_score
testResults = model.predict(testSamples)

print(confusion_matrix(testLabels.argmax(axis=1), testResults.argmax(axis=1)))
print(classification_report(testLabels.argmax(axis=1), testResults.argmax(axis=1)))
print("CNN Accuracy: {:.2f}".format(accuracy_score(testLabels.argmax(axis=1), testResults.argmax(axis=1))))
print("Cohen's Kappa: {:.2f}".format(cohen_kappa_score(testLabels.argmax(axis=1), testResults.argmax(axis=1))))
# Out:
# [[774  27]
#  [ 67 681]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       801
#            1       0.96      0.91      0.94       748
#
#     accuracy                           0.94      1549
#    macro avg       0.94      0.94      0.94      1549
# weighted avg       0.94      0.94      0.94      1549
#
# CNN Accuracy: 0.94
# Cohen's Kappa: 0.88

# %% [markdown]
# ## Loss and accuracy in epochs

# %%
import matplotlib.pyplot as plt
N = np.arange(0, len(H.history["loss"]))

fig,(loss_plot,acc_plot) = plt.subplots(1,2, figsize=(12, 5))

loss_plot.plot(N, H.history["loss"], label="train_loss")
loss_plot.plot(N, H.history["val_loss"], label="val_loss")
loss_plot.set_title("Loss")
loss_plot.set(xlabel='Epoch #', ylabel='Loss')
loss_plot.legend()

acc_plot.plot(N, H.history["accuracy"], label="train_accuracy")
acc_plot.plot(N, H.history["val_accuracy"], label="val_accuracy")
acc_plot.set_title("Accuracy")
acc_plot.set(xlabel='Epoch #', ylabel='Accuracy')
acc_plot.legend()

# %% [markdown]
# ## kNN/DecisionTree classifier (for comparison)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,cohen_kappa_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# flatten samples
flat_samples = samples
flat_samples = np.reshape(flat_samples,newshape=(202,-1))
print("Samples shape flattened",flat_samples.shape)

(trainSamples, testSamples, trainLabels, testLabels) = sklearn.model_selection.train_test_split(flat_samples,labels,random_state=42)

# choose classifier
knnmodel = DecisionTreeClassifier()
#knnmodel = KNeighborsClassifier()

# fit model
knnmodel.fit(trainSamples, trainLabels)
knnResults = knnmodel.predict(testSamples)    

# show results
print(confusion_matrix(testLabels.argmax(axis=1), knnResults.argmax(axis=1)))
print(classification_report(testLabels.argmax(axis=1), knnResults.argmax(axis=1)))
knnAcc = accuracy_score(testLabels.argmax(axis=1), knnResults.argmax(axis=1)) 
print("kNN Accuracy: {:.2f}".format(knnAcc))
print("Cohen's Kappa: {:.2f}".format(cohen_kappa_score(testLabels.argmax(axis=1), knnResults.argmax(axis=1))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-73a23dbb1dcf> in <module>
#       5 # flatten samples
#       6 flat_samples = samples
# ----> 7 flat_samples = np.reshape(flat_samples,newshape=(202,-1))
#       8 print("Samples shape flattened",flat_samples.shape)
#       9
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~\.conda\envs\abc\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# ~\.conda\envs\abc\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 304398336 into shape (202,newaxis)

# %%
model.save("final_model.h5")
